# %%
print("Hello, Data Science! My name is Rwotngeyo Roy Innocent")
# Out:
# Hello, Data Science! My name is Rwotngeyo Roy Innocent

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.13.2 (v3.13.2:4f8bb3947cf, Feb  4 2025, 11:51:10) [Clang 15.0.0 (clang-1500.3.9.4)]
